# %% [markdown]
# # Маркетинговый анализ приложения

# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта:" data-toc-modified-id="Описание-проекта:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта:</a></span><ul class="toc-item"><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание данных</a></span></li><li><span><a href="#Цели-исследования" data-toc-modified-id="Цели-исследования-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Цели исследования</a></span></li></ul></li><li><span><a href="#Загрузим-данные-и-подготовим-их-к-анализу" data-toc-modified-id="Загрузим-данные-и-подготовим-их-к-анализу-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Загрузим данные и подготовим их к анализу</a></span><ul class="toc-item"><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обзор данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Приведём-столбцы-к-единому-регистру" data-toc-modified-id="Приведём-столбцы-к-единому-регистру-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Приведём столбцы к единому регистру</a></span></li><li><span><a href="#Поменяем-типы-данных" data-toc-modified-id="Поменяем-типы-данных-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Поменяем типы данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Подготовка-функций-для-расчёта-и-анализа-основных-метрик" data-toc-modified-id="Подготовка-функций-для-расчёта-и-анализа-основных-метрик-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Подготовка функций для расчёта и анализа основных метрик</a></span><ul class="toc-item"><li><span><a href="#Функция-для-профилей" data-toc-modified-id="Функция-для-профилей-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Функция для профилей</a></span></li><li><span><a href="#Функция-для-удержания" data-toc-modified-id="Функция-для-удержания-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Функция для удержания</a></span></li><li><span><a href="#Функция-для-конверсии" data-toc-modified-id="Функция-для-конверсии-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Функция для конверсии</a></span></li><li><span><a href="#Функция-для-LTV,-ROI" data-toc-modified-id="Функция-для-LTV,-ROI-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Функция для LTV, ROI</a></span></li><li><span><a href="#Функции-для-визуализации-удержания,-конверсии,-LTV-и-ROI" data-toc-modified-id="Функции-для-визуализации-удержания,-конверсии,-LTV-и-ROI-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Функции для визуализации удержания, конверсии, LTV и ROI</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Момент-и-горизонт-анализа" data-toc-modified-id="Момент-и-горизонт-анализа-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Момент и горизонт анализа</a></span></li><li><span><a href="#Профили-пользователей" data-toc-modified-id="Профили-пользователей-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Профили пользователей</a></span><ul class="toc-item"><li><span><a href="#Анализ-пользователей-по-странам" data-toc-modified-id="Анализ-пользователей-по-странам-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Анализ пользователей по странам</a></span></li><li><span><a href="#Анализ-пользователей-по-устройствам" data-toc-modified-id="Анализ-пользователей-по-устройствам-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Анализ пользователей по устройствам</a></span></li><li><span><a href="#Анализ-пользователей-по-рекламным-источникам" data-toc-modified-id="Анализ-пользователей-по-рекламным-источникам-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Анализ пользователей по рекламным источникам</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Маркетинг</a></span><ul class="toc-item"><li><span><a href="#Расходы-на-рекламу" data-toc-modified-id="Расходы-на-рекламу-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Расходы на рекламу</a></span></li><li><span><a href="#Стоимость-привлечения-пользователя" data-toc-modified-id="Стоимость-привлечения-пользователя-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Стоимость привлечения пользователя</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Оценим-окупаемость-рекламы-для-привлечения-пользователей" data-toc-modified-id="Оценим-окупаемость-рекламы-для-привлечения-пользователей-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Оценим окупаемость рекламы для привлечения пользователей</a></span><ul class="toc-item"><li><span><a href="#Общая-окупаемость-рекламы" data-toc-modified-id="Общая-окупаемость-рекламы-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Общая окупаемость рекламы</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.1.1"><span class="toc-item-num">7.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Окупаемость-по-странам" data-toc-modified-id="Окупаемость-по-странам-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Окупаемость по странам</a></span><ul class="toc-item"><li><span><a href="#Анализ-конверсии-и-удержания-по-странам" data-toc-modified-id="Анализ-конверсии-и-удержания-по-странам-7.2.1"><span class="toc-item-num">7.2.1&nbsp;&nbsp;</span>Анализ конверсии и удержания по странам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.2.2"><span class="toc-item-num">7.2.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Окупаемость-по-рекламным-каналам" data-toc-modified-id="Окупаемость-по-рекламным-каналам-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Окупаемость по рекламным каналам</a></span><ul class="toc-item"><li><span><a href="#Анализ-конверсии-и-удержания-с-разбивкой-по-каналам-привлечения" data-toc-modified-id="Анализ-конверсии-и-удержания-с-разбивкой-по-каналам-привлечения-7.3.1"><span class="toc-item-num">7.3.1&nbsp;&nbsp;</span>Анализ конверсии и удержания с разбивкой по каналам привлечения</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.3.2"><span class="toc-item-num">7.3.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Окупаемость-по-устройствам" data-toc-modified-id="Окупаемость-по-устройствам-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Окупаемость по устройствам</a></span><ul class="toc-item"><li><span><a href="#Анализ-конверсии-и-удержания-с-разбивкой-по-устройствам" data-toc-modified-id="Анализ-конверсии-и-удержания-с-разбивкой-по-устройствам-7.4.1"><span class="toc-item-num">7.4.1&nbsp;&nbsp;</span>Анализ конверсии и удержания с разбивкой по устройствам</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-7.4.2"><span class="toc-item-num">7.4.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Выводы</a></span><ul class="toc-item"><li><span><a href="#Рекомендации" data-toc-modified-id="Рекомендации-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Рекомендации</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Описание проекта:
#
# Для анализа представлены данные развлекательного приложения.
#
# *Суть проблемы:*
# Последние несколько месяцев компания несёт убытки, несмотря на то, что в привлечение пользователей были вложены большие деньги.
#
# *Исходные данные:*
# В нашем распоряжении имеется лог сервера с данными о посещениях приложения новыми пользователями, зарегистрировавшимися в период с 2019-05-01 по 2019-10-27, выгрузка их покупок за этот период, а также статистика рекламных расходов.
# В ходе анализа данных необходимо понять, как пользователи пользуются продуктом, когда они начинают покупать, сколько прибыли приносит каждый клиент, когда он окупается и какие факторы отрицательно влияют на привлечение пользователей.
#
#
# ### Описание данных
# 1. Таблица visits_log_short (лог сервера с информацией о посещениях сайта):
#     - User Id — уникальный идентификатор пользователя
#     - Device — категория устройства пользователя
#     - Session start — дата и время начала сессии
#     - Session End — дата и время окончания сессии
#     - Channel — идентификатор рекламного источника, из которого пришел пользователь
#     - Region - страна пользователя
#
#
# 2. Таблица orders_log_short (информация о заказах):
#     - User Id — уникальный id пользователя, который сделал заказ
#     - Event Dt — дата и время покупки
#     - Revenue — выручка
#
#
# 3. Таблица costs_short (информация о затратах на маркетинг):
#     - Channel — идентификатор рекламного источника
#     - Dt — дата
#     - Costs — затраты на этот рекламный источник в этот день
#
#
# *P.S.:*
# *Поскольку в условиях проекта не указана денежная единица, примем в качестве таковой российский рубль.*
#
# ### Цели исследования
#
# - выяснить причины возникновения убытков компании за последние несколько месяцев (неэффективности привлечения пользователей),
# - найти способы снижения убытков и увеличения прибыли и дать соовтетствующие рекомендации отделу маркетинга для повышения эффективности привлечения пользователей.

# %% [markdown]
# ## Загрузим данные и подготовим их к анализу

# %% [markdown]
# ### Обзор данных

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
pd.options.display.float_format = '{:.3f}'.format

# %%
visits = pd.read_csv('visits_info_short.csv')
orders = pd.read_csv('orders_info_short.csv')
costs =  pd.read_csv('costs_info_short.csv')

# %%
# функция для обзора информации о каждом из датафреймов

def inf(df):
    display(df.info());
    display(df.head());
    print('Дубликатов:', df.duplicated().sum());

# %%
# функция для обзора информации о каждом из датафреймов

def inf_rev(df):
    df.info()
    display(df.head());
    print('Дубликатов:', df.duplicated().sum());
    
inf_rev(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# ...

# %%
inf(visits)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# None
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
# ...

# %%
inf(orders)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# None
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52    4.990
# 1  174361394180  2019-05-01 12:24:04    4.990
# 2  529610067795  2019-05-01 11:34:04    4.990
# 3  319939546352  2019-05-01 15:34:40    4.990
# 4  366000285810  2019-05-01 13:59:51    4.990
# Дубликатов: 0

# %%
inf(costs)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB
# None
#            dt   Channel   costs
# 0  2019-05-01  FaceBoom 113.300
# 1  2019-05-02  FaceBoom  78.100
# 2  2019-05-03  FaceBoom  85.800
# 3  2019-05-04  FaceBoom 136.400
# 4  2019-05-05  FaceBoom 122.100
# Дубликатов: 0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Для анализа представлены три датафрейма:
# - *visits* - с информацией о посещениях сайта,
# - *orders* - с информацией о покупках,
# - *costs* - с информацией о расходах на рекламу.
#
# Датафреймы представлены в "чистом" виде - нет пропусков и явных дупликатов.
# Однако необходма небольшая предобработка - откорректировать некорректные наименования столбцов, а также поменять типы данных в столбцах с датами на datetime для последующей работы с ними.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Приведём столбцы к единому регистру

# %% [markdown]
# Приведём названия столбцов к нижнему регистру

# %%
visits.columns = visits.columns.str.lower()
orders.columns = orders.columns.str.lower()
costs.columns = costs.columns.str.lower()

# %% [markdown]
# В датафреймах visits и orders также приведём столбцы к "змеиному регистру"

# %%
visits.columns = [x.lower().replace(' ', '_') for x in visits.columns]

orders.columns = orders.columns = [x.lower().replace(' ', '_') for x in orders.columns]

# %%
orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %% [markdown]
# ### Поменяем типы данных

# %% [markdown]
# Все столбцы с датами приведём к формату datetime

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])
orders['event_dt'] = pd.to_datetime(orders['event_dt'])
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
print(visits.dtypes);
print()
print(orders.dtypes);
print()
print(costs.dtypes)
# Out:
# user_id                   int64
# region                   object
# device                   object
# channel                  object
# session_start    datetime64[ns]
# session_end      datetime64[ns]
# dtype: object
#
# user_id              int64
# event_dt    datetime64[ns]
# revenue            float64
# dtype: object
#
# dt          object
# channel     object
# costs      float64
# dtype: object

# %% [markdown]
# ### Вывод

# %% [markdown]
# В результате проведённой предобработки мы привели названия столбцов к единому регистру, а также поменяли типы данных на datetime во всех столбцах с датами для последующей работы с ними.

# %% [markdown]
# ## Подготовка функций для расчёта и анализа основных метрик

# %% [markdown]
# Подготовим функции:
# - для создания профилей *get_profiles()*,
# - для расчёта удержания *get_retention()*,
# - для расчёта конверсии *get_conversion()*,
# - для расчёта LTV и ROI *get_ltv()*,
# - для визуализации удержания, конверсии, LTV и ROI

# %% [markdown]
# ### Функция для профилей

# %%
# функция для создания пользовательских профилей

def get_profiles(sessions, orders, ad_costs):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # определяем дату первого посещения и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# ### Функция для удержания

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для конверсии

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# ### Функция для LTV, ROI

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# ### Функции для визуализации удержания, конверсии, LTV и ROI

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(20, 15))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(horizon), fontsize=(10)
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 15))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм', fontsize=(15))
    plt.title('LTV', fontsize=(17))

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения', fontsize=(15))
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon), fontsize=(17))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения', fontsize=(15))
    plt.title('Динамика стоимости привлечения пользователей', fontsize=(17))

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм', fontsize=(15))
    plt.title('ROI', fontsize=(17))

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения', fontsize=(15))
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon), fontsize=(17))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Момент и горизонт анализа

# %% [markdown]
# Определим минимальную и максимальную даты привлечения пользователей для определения периода анализа

# %%
min_date = visits.groupby('user_id').agg({'session_start':'min'})\
            .rename(columns={'session_start':'min_date'})\
            .sort_values(by='min_date').head(1)

max_date = visits.groupby('user_id').agg({'session_end':'max'})\
            .rename(columns={'session_end':'max_date'})\
            .sort_values(by='max_date', ascending=False).head(1)

print('Минимальная дата привлечения пользователей:')
display(min_date)

print('Максимальная дата привлечения пользователей:')
display(max_date)
# Out:
# Минимальная дата привлечения пользователей:
#                         min_date
# user_id
# 382394863972 2019-05-01 00:00:41
# Максимальная дата привлечения пользователей:
#                         max_date
# user_id
# 184260303823 2019-11-01 01:38:46

# %%
min_date_rev = visits['session_end'].min()
max_date_rev = visits['session_end'].max()

max_date_rev - min_date_rev
# Out:
# Timedelta('184 days 01:31:40')

# %% [markdown]
# **Период анализа**: с 01.05.2019 по 01.11.2019, т.е. **6 месяцев.**  Данный период соответствует указанному в исходном задании.

# %% [markdown]
# Анализируем данные по состоянию на 1-е ноября 2019 года.
# Примем за данность, что в нашем приложении окупаемость должна наступать не позднее, чем через 2 недели после привлечения пользователей.
# Исходя из этого, **установим момент и горизонт анализа данных: 1 ноября 2019 года и 14 дней соответственно.**

# %%
# момент анализа
observation_date = datetime(2019, 11, 1).date()

# горизонт анализа
horizon_days = 14

# %% [markdown]
# ### Профили пользователей

# %% [markdown]
# Получим профили пользователей: вызовем функцию get_profiles(), передав ей данные о посещениях, покупках и тратах на рекламу

# %%
profiles = get_profiles(visits, orders, costs)
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True             1.088
# 1  2019-07-09 2019-07-01  False             1.107
# 2  2019-10-01 2019-10-01  False             0.000
# 3  2019-08-22 2019-08-01  False             0.988
# 4  2019-10-02 2019-10-01  False             0.231

# %% [markdown]
# #### Анализ пользователей по странам

# %% [markdown]
# Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей.
# Построим таблицу, отражающую общее количество пользователей, количество платящих пользователей и долю платящих в каждой из стран.

# %%
# функция для вывода таблицы и диаграмм 
# с общим количеством пользователей и долей платящих пользователей
# по каждому из необходимых параметров (страна, девайс, канал привлечения)

def for_table(col, name):
    print('Распределение пользователей по', name)
    
    # построение таблицы
    table = profiles.groupby(col).agg({'user_id':'nunique', 'payer':'mean'})\
    .sort_values(by=['user_id', 'payer'], ascending=False)
    display(table.style.format({'payer': '{:1.1%}'}))
    
    plt.figure(figsize=(20, 20))
    
    # построение круговой диаграммы по общему количеству пользователей
    ax1 = plt.subplot(2, 2, 1)
    table.user_id.sort_values(ascending=False)\
    .plot(kind='pie', ylabel='user_id', autopct='%1.1f%%')
    plt.xlabel('')
    plt.ylabel('')
    plt.title('Диаграмма распределения общего количества пользователей', fontsize=15)
    plt.show;
    
    # построение диаграммы по долям платящих пользователей
    ax2 = plt.subplot(2, 2, 2)
    table.payer.sort_values(ascending=False)\
    .plot(kind='bar', grid=True, xlabel=col, ylabel='payer')
    plt.xlabel('')
    plt.ylabel('доля платящих', fontsize=12)
    plt.title('Диаграмма распределения доли платящих пользователей', fontsize=15)
    plt.show;

# %%
for_table('region', 'странам')
# Out:
# Распределение пользователей по странам
# <style  type="text/css" >
# </style><table id="T_c5a89_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="index_name level0" >region</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c5a89_level0_row0" class="row_heading level0 row0" >United States</th>
#                         <td id="T_c5a89_row0_col0" class="data row0 col0" >100002</td>
#                         <td id="T_c5a89_row0_col1" class="data row0 col1" >6.9%</td>
#             </tr>
#             <tr>
#                         <th id="T_c5a89_level0_row1" class="row_heading level0 row1" >UK</th>
#                         <td id="T_c5a89_row1_col0" class="data row1 col0" >17575</td>
# ...

# %% [markdown]
# 66,7% общего количества пользователей приходятся на США, остальная часть пользователей примерно равномерно распределена между другими странами: Великобританией (11,7%), Германией (10%) и Францией (11,6%).

# %% [markdown]
# Большая часть платящих пользователей также находится в США - 77,7% от общего числа платящих в этой стране. В остальных странах количество платящих значительно ниже: Великобритания - 7,9%, Франция - 7,5%, Германия - 6,9%.

# %% [markdown]
# При этом доля платящих в каждой из представленных стран составляет менее 7%:
# - США - 6,9%,
# - Германия 4,1%,
# - Великобритания - 4%,
# - Франция - 3,8 %

# %% [markdown]
# **Больше всего пользователей пришло из США (77,7%) и в США больше всего доля платящих пользователей (6,9%).**

# %% [markdown]
# #### Анализ пользователей по устройствам

# %% [markdown]
# Теперь выясним, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
for_table('device', 'устройствам')
# Out:
# Распределение пользователей по устройствам
# <style  type="text/css" >
# </style><table id="T_e4314_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="index_name level0" >device</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4314_level0_row0" class="row_heading level0 row0" >iPhone</th>
#                         <td id="T_e4314_row0_col0" class="data row0 col0" >54479</td>
#                         <td id="T_e4314_row0_col1" class="data row0 col1" >6.2%</td>
#             </tr>
#             <tr>
#                         <th id="T_e4314_level0_row1" class="row_heading level0 row1" >Android</th>
#                         <td id="T_e4314_row1_col0" class="data row1 col0" >35032</td>
# ...

# %% [markdown]
# В отличие от распределения по странам, распределение по устройстам более равномерное. С небольшим перевесом лидируют пользователи **iPhone** - они составляют **36%** от общего числа. На втором месте по популярности - пользователи **Android** - у них примерно **23%**. Пользователи **Mac и PC** занимают 3 место - у них по **20%**.

# %% [markdown]
# Доля платящих чуть выше на устройстах Mac и iPhone (6%), что объясняет платность всех приложений операционной системы IOS в целом. Самый низкий показатель платящих пользователей PC - 5%.
# Тем не менее распределение доли платящих по всем устройстам примерно одинаково и является очень низким - практически не превышает 6%.

# %% [markdown]
# #### Анализ пользователей по рекламным источникам

# %% [markdown]
# Определим каналы, из которых пришло больше всего платящих пользователей.
# Построим таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
for_table('channel', 'источникам привлечения')
# Out:
# Распределение пользователей по источникам привлечения
# <style  type="text/css" >
# </style><table id="T_6be20_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >user_id</th>        <th class="col_heading level0 col1" >payer</th>    </tr>    <tr>        <th class="index_name level0" >channel</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6be20_level0_row0" class="row_heading level0 row0" >organic</th>
#                         <td id="T_6be20_row0_col0" class="data row0 col0" >56439</td>
#                         <td id="T_6be20_row0_col1" class="data row0 col1" >2.1%</td>
#             </tr>
#             <tr>
#                         <th id="T_6be20_level0_row1" class="row_heading level0 row1" >FaceBoom</th>
#                         <td id="T_6be20_row1_col0" class="data row1 col0" >29144</td>
# ...

# %% [markdown]
# Больше всего пользователей приходят в приложение самостоятельно - 37.6% (*organic*). Но среди органических пользователей меньше всего и доля платящих - всего 2%.
#
# Из платных каналов привлечения самым плодотворным является *FaceBoom* и по общему числу привлечённых пользователей (19.4%) и по доле платящих в нём (12%).
# Канал  *TipTop* привлекает 13% пользователей, однако доля платящих на этом канале - всего 9.6%.
# Каналы *OppleCreativeMedia*, *WahooNetBanner* и *LeapBob* привлекают по 5.7% каждый, доля платящих в них также ниже (2.7%, 5.3%, 3.1% соответственно).
# Остальные каналы привлекают от 1.5% до 3% пользователей каждый.
# При этом обращаем внимание, что на каналах *AdNonSense* и *lambdaMediaAds*, несмотря на низкий процент привлечения пользователей (2.6% и 1.4%), доля платящих в них 10,5-11%, то есть практически как у лидера FaceBoom. То есть потенциально эти две платформы могут приносить больше денег, если увеличить в них общее число пользователей.

# %%
profiles.pivot_table(index='dt', columns='channel', values='user_id', aggfunc='nunique')\
        .plot(grid=True, figsize=(20,10))

plt.title('Динамика привлечения новых пользователей по каждому из рекламных каналов', fontsize=15)
plt.ylabel('количество пользователей')
plt.xlabel('')
plt.show();

# %% [markdown]
# На графике виден резкий скачок в привлечении новых органических пользователей в мае, однако к июню их количество также резко спало вдвое.
# В мае же также наблюдается небольшая просадка по новым пользователях FaceBoom и TipTop - их количество едва превышало 100, но с июня их позиции улучшились и выравнились: по 100-250 новых пользователей в месяц.

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. Больше всего пользователей пришло из США (77,7%) и в США больше всего доля платящих пользователей (6,9%).
#
#
# 2. Распределение пользователей по всем четырём устройствам примерно одинаковое, с небольшим перевесом у IPhone (36%). Hаспределение доли платящих по всем устройстам примерно одинаково и является очень низким - практически не превышает 6%.
#
#
# 3. Треть всех пользователей пришли в приложение самостоятельно (37%).
# Из платных каналов привлечения самым плодотворным является *FaceBoom* и по общему числу привлечённых пользователей (19.4%) и по доле платящих в нём (12%).
# Канал  *TipTop* привлекает 13% пользователей, однако доля платящих на этом канале - всего 9.6%.
# Yа каналах *AdNonSense* и *lambdaMediaAds*, несмотря на низкий процент привлечения пользователей (2.6% и 1.4%), доля платящих в них 10,5-11%, то есть практически как у лидера FaceBoom. То есть потенциально эти две платформы могут приносить больше денег, если увеличить в них общее число пользователей.

# %% [markdown]
# ## Маркетинг

# %% [markdown]
# ### Расходы на рекламу

# %% [markdown]
# Посчитаем общую сумму расходов на маркетинг и распределение расходов по источникам.

# %%
costs_total = round(costs.costs.sum())
print('Общая сумма расходов на маркетинг составила', costs_total, 'рублей.')

costs_table = costs.pivot_table(index='channel', values='costs', aggfunc='sum')

# добавим столбец с выделением доли относительно общей суммы расходов на рекламу
costs_table['ratio'] = costs_table['costs'] / costs_total
costs_table = costs_table.sort_values(by='costs', ascending=False)
print('Расходы на рекламу по каналам:')
display(costs_table)
# Out:
# Общая сумма расходов на маркетинг составила 105497 рублей.
# Расходы на рекламу по каналам:
#                        costs  ratio
# channel
# TipTop             54751.300  0.519
# FaceBoom           32445.600  0.308
# WahooNetBanner      5151.000  0.049
# AdNonSense          3911.250  0.037
# OppleCreativeMedia  2151.250  0.020
# RocketSuperAds      1833.000  0.017
# LeapBob             1797.600  0.017
# lambdaMediaAds      1557.600  0.015
# MediaTornado         954.480  0.009
# YRabbit              944.220  0.009

# %%
# построим диаграмму распределения расходов на рекламу по каналам

costs_table.costs\
    .plot(kind='pie', ylabel='channel', autopct='%1.1f%%', legend=False, figsize=(10, 10))
plt.xlabel('')
plt.ylabel('')
plt.title('Диаграмма распределения расходов на рекламу', fontsize=15)
plt.show();

# %% [markdown]
# *Больше половины всех расходов на рекламу были направлены на канал TipTop (52%), ещё почти треть - на FaceBoom (31%). На оставшиеся 8 источников в сумме пришлось лишь 17% всех рекламных расходов.*

# %% [markdown]
# Проследим динамику изменения расходов на рекламу в целом и по каждому из источников.

# %%
# построим общий график динамики изменения расходов на рекламу

costs.groupby('dt').agg({'costs':'sum'}).sort_values(by='costs', ascending=False)\
    .plot(grid=True, figsize=(10,5))
plt.xlabel('')
plt.ylabel('расходы на рекламу')
plt.title('Общий график изменения расходов на рекламу', fontsize=15)
plt.show;

# %%
# построим график динамики изменения расходов на рекламу по каналам

costs.pivot_table(index='dt', columns='channel', values='costs', aggfunc='sum')\
    .plot(grid=True, figsize=(15,10))

plt.xlabel('')
plt.ylabel('расходы на рекламу')
plt.title('График изменения расходов на рекламу по каналам', fontsize=15)
plt.legend(loc='upper left')
plt.show;

# %% [markdown]
# Приблизим график и посмотрим на динамику изменения расходов на рекламу по нелидирующим каналам

# %%
costs.query('channel != ["TipTop", "FaceBoom"]')\
    .pivot_table(index='dt', columns='channel', values='costs', aggfunc='sum')\
    .plot(grid=True, figsize=(15,10))

plt.xlabel('')
plt.ylabel('расходы на рекламу')
plt.title('График изменения расходов на рекламу по "дешёвым" каналам', fontsize=15)
plt.legend(loc='upper left')
plt.show;

# %% [markdown]
# *Общая тенденция расходов на рекламу за последние 6 месяцев - их увеличение. При этом если смотреть распределение по каналам, то увеличение расходов происходило только в отношении каналов TipTop и FaceBoom. При этом в TipTop владывали денег больше всего: начиная с июня вливания в рекаламу на TipTop увеличивалось с каждым месяцем в 1.5-2 раза, а в октябре и достигло пика за весь рассматриваемый период.*
# Что касается менее крупных каналов - то в среди них выделяется AdNoneSense, чьи расходы на рекламу снизились в июне вдвое. Остальные каналы примерно равномерно расходовали рекламные средства.

# %% [markdown]
# ### Стоимость привлечения пользователя

# %% [markdown]
# Узнаем, сколько в среднем стоило привлечение одного пользователя из каждого источника (органический источник исключаем, т.к. он бесплатный).

# %%
cac = profiles.query('channel != "organic"')\
        .pivot_table(index='channel', values='acquisition_cost', aggfunc='mean')\
        .sort_values(by='acquisition_cost', ascending=False)

print('Распределение средней стоимости привлечения пользователей по каналам')
display(cac)

cac.plot(kind='bar', grid=True, figsize=(10,5))
plt.xlabel('')
plt.ylabel('средний САС')
#plt.title('Распределение средней стоимости привлечения покупателей по каналам', fontsize=15)
plt.show();
# Out:
# Распределение средней стоимости привлечения пользователей по каналам
#                     acquisition_cost
# channel
# TipTop                         2.799
# FaceBoom                       1.113
# AdNonSense                     1.008
# lambdaMediaAds                 0.725
# WahooNetBanner                 0.602
# RocketSuperAds                 0.412
# OppleCreativeMedia             0.250
# YRabbit                        0.219
# MediaTornado                   0.219
# LeapBob                        0.210

# %% [markdown]
# Средняя стоимость привлечения одного пользователя в TipTop в 2.5-3 раза превышает стоимость по другим каналам и составляет 2.8 рубля.
# Рассмотрим тот же показатель в динамике.

# %%
profiles.query('channel != "organic"')\
        .pivot_table(index='dt', columns='channel', values='acquisition_cost', aggfunc='mean')\
        .plot(grid=True, figsize=(15,10))

plt.ylabel('средний САС')
plt.title('Динамика распределения средней стоимости привлечения пользователей по каналам', fontsize=15)
plt.show();

# %% [markdown]
# Средняя стоимость привлечения пользователя в TipTop с каждым месяцем только росла (показатель в 1,5-2 раза выше предыдущего месяца), при этом динамика по остальным каналам практически не менялась.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Общая сумма расходов на маркетинг составила 105 497 рублей. Из них больше половины всех расходов на рекламу были направлены на канал TipTop (52%), ещё почти треть - на FaceBoom (31%). На оставшиеся 8 источников в сумме пришлось лишь 17% всех рекламных расходов.
#
# Общая тенденция расходов на рекламу за последние 6 месяцев - их увеличение. При этом если смотреть распределение по каналам, то увеличение расходов происходило только в отношении каналов TipTop и FaceBoom. При этом в TipTop владывали денег больше всего: начиная с июня вливания в рекаламу на TipTop увеличивалось с каждым месяцем в 1.5-2 раза, а в октябре и достигло пика за весь рассматриваемый период.
#
# Средняя стоимость привлечения пользователя в TipTop с каждым месяцем только росла (показатель в 1,5-2 раза выше предыдущего месяца), при этом динамика по остальным каналам практически не менялась.

# %% [markdown]
# ## Оценим окупаемость рекламы для привлечения пользователей

# %% [markdown]
# ### Общая окупаемость рекламы

# %% [markdown]
# Для начала оценим *общую окупаемость рекламы.*
# Рассчитаем и визуализируем LTV и ROI, вызвав ранее подготовленные функции.

# %%
# считаем LTV и ROI
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days
)

# строим графики
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# #### Вывод

# %% [markdown]
# - Общая выручка от пользователей выросла, но при этом выросла и стоимость их привлечения.
# - Резкий скачок в средней стимости привлечения пользователей произошёл в июне и практически не снижался.
# - Судя по графику ROI реклама не окупается вовсе - в концу второй недели показатель ROI чуть выше 80%.
# - В динамике окупаемость рекламы стала пропадать как раз тогда, когда подскочили расходы на привлечение пользователей.

# %% [markdown]
# *Чтобы разобраться в причинах неокупаемости рекламы, пройдёмся по всем доступным характеристикам пользователей — стране, источнику и устройству первого посещения.*

# %% [markdown]
# ### Окупаемость по странам

# %%
# смотрим окупаемость с разбивкой по странам

# передадим параметру dimensions столбец region

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# - По уровню окупаемости только США показывает плохой показатель - ROI в конце недели чуть выше 0.7. При этом другие страны показывают результаты выше 1 уже со 2-3 дня.
# - Динамика привлечения пользователей также говорит о сильном снижении ROI в США: с конца июня ROI стал ниже уровня окупаемости.
# - При этом стоимость привленичения пользователей в США, напротив, стремительно растёт, между тем как по остальным странам она снижается.
#
# По графикам показатели CАC и ROI по США очень напоминают общие CАС и ROI. Вероятно проблемы нужно искать именно в этой стране.

# %% [markdown]
# *Чтобы определить причины такого распределения окупаемости по странам, рассмотрим конверсию и удержание*

# %% [markdown]
# #### Анализ конверсии и удержания по странам

# %%
# смотрим конверсию с разбивкой по странам

dimensions = ['region']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Конверсия по всех странах в середине мая была примерно одинаково высокой. Однако потом резко стала снижаться везде, кроме США. Конверсия в США самая высокая. Возможно, в этой стране дело в удержании.

# %%
# смотрим удержание с разбивкой по странам

dimensions = ['region']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('channel != "organic"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Действительно, удержание платящих пользователей в США самое низкое.
# Если платящие пользователи уходят, реклама соответственно не окупается.
# Динамика удержания в остальных странах скачкообразная - возможно резкие взлёты и падения связаны с какими-то рекламными компаниями:
# - Великобритания: середина июня - резкий скачок, начало августа - падение,
# - Франция: конец июля, начало сентября и начало октября - скачки, начало августа - падение,
# - Германия: середина июля, середина сентября, конец октября - скачки, середина мая, конец июня, середина октября - падения.

# %% [markdown]
# #### Вывод

# %% [markdown]
# **Реклама в США не окупается вообще.**
# Возможной причиной этого является низкое удержание платящих пользователей и высокая стоимость привлечения пользователей.
# Также следует обратить внимание на резкое снижение конверсии в остальных странах с конца мая, а также на скачки в удержании этих стран.

# %% [markdown]
# ### Окупаемость по рекламным каналам

# %%
# смотрим окупаемость с разбивкой по источникам привлечения

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# - Самый высокий LTV - на канале LambdaMediaAds, на втором месте TipTop.
# - При этом окупаемость LambdaMediaAds значительно выше окупаемости TipTop.
# - Самая высокая окупаемость на канале YRabbit
# - Стоимость привлечения на канале TipTop с каждым месяцем увеличивается в два раза, при этом показатель окупаемости у этого канала - самый низкий. В остальных каналах средняя стоимость не менялась.
# - TipTop вместе с FaceBoom и AdNoneSense не окупаются вообще.
#
#
# По графикам показатели CАC и ROI в TipTop очень напоминают общие CАС и ROI. Вероятно проблемы связаны в основном  с этим каналом привлечения (а также аналогичная ситуация в США).

# %% [markdown]
# *Для понимания причин - проанализаруем конверсию и удержание по каналам привлечения.*

# %% [markdown]
# #### Анализ конверсии и удержания с разбивкой по каналам привлечения

# %%
# смотрим конверсию с разбивкой по каналам

dimensions = ['channel']
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
# смотрим удержание с разбивкой по каналам

dimensions = ['channel']
retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('channel != "organic"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# #### Вывод

# %% [markdown]
# **Хуже всего окупаются TipTop и FaceBoom.**
#
# Конверсия в платящих пользователей по всем каналам очень низкая.
# Низкая окупаемость FaceBoom объясняется низким удержанием платящих пользователей.
# TipTop не окупается из-за совокупности низкой конверсии и высокой стоимости привлечения пользователей.

# %% [markdown]
# ### Окупаемость по устройствам

# %% [markdown]
# Посмотрим окупаемость с разбивкой по устройствам

# %%
# передадим параметру dimensions столбец device

dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_ltv_roi(
    ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days, window=14
)

# %% [markdown]
# - Реклама на устройствах Mac, IPhone И Android вообще не окупаются.
# - Из всех устройств окупаемость есть только у рекламы на устройстве PC и только с 11 дня привлечения. На этом устройстве окупаемость резко пошла вниз с августа, а с сентября реклама на устройстве не окупается вообще.
# - Cтоимость привлечения на устройствах Mac и IPhone выше, чем на Android и PC.
# - Динамика по всем устройствам показывает общее снижение окупаемости рекламы уже с июня.

# %% [markdown]
# *Узнаем, в чём причина: в низкой конверсии или низком удержании.*

# %% [markdown]
# #### Анализ конверсии и удержания с разбивкой по устройствам

# %%
# смотрим конверсию с разбивкой по устройствам

conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles.query('channel != "organic"'), orders, observation_date, horizon_days, dimensions=dimensions
)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Судя по графикам, пользователи iPhone и Mac конвертируются очень хорошо, причём постоянно.
# Хуже всего конвертация в платящих у пользователей PC.

# %%
# смотрим удержание с разбивкой по устройствам

retention_raw, retention_grouped, retention_history = get_retention(
    profiles.query('channel != "organic"'), visits, observation_date, horizon_days, dimensions=dimensions
)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Конверсия в платящих пользователей на PC самая низкая, однако на этом устройстве самый высокий показатель удержания.
#
# У пользователей Мас и IPhone, напротив, конверсия высокая, однако удержание плохое.
#
# В конце мая и в середине июля наблюдались резкие скачки в удержании платящих пользователей на Мас и IPhone. Аналогичный скачок наблюдается у пользователей PC, но в середине мая.
# Стоит проверить эти временные отрезки - возможно в эти периоды события или проводились рекламные компании, которые привели к росту удержания на этих устройствах.

# %% [markdown]
# #### Вывод

# %% [markdown]
# **Cтоимость привлечения на устройствах Mac и IPhone выше, но они вообще не окупаются.**
# Возможная причина этого - низкое удержание при высокой конверсии вкупе с с высокой стоимостью привлечения пользователей.
#
# **Cтоимость привлечения на PC и Android ниже, при этом их окупаемость выше, чем на Mac и IPhone.**
# Конверсия в платящих пользователей на PC самая низкая, однако на этом устройстве самый высокий показатель удержания.
#
# В конце мая и в середине июля наблюдались резкие скачки в удержании платящих пользователей на Мас и IPhone. Аналогичный скачок наблюдается у пользователей PC, но в середине мая.
# Стоит проверить эти временные отрезки - возможно в эти периоды события или проводились рекламные компании, которые привели к росту удержания на этих устройствах.

# %% [markdown]
# ## Выводы

# %% [markdown]
# 1. Больше всего пользователей пришло из США (77,7%) и в США больше всего доля платящих пользователей (6,9%).
#
#
# 2. Распределение пользователей по всем четырём устройствам примерно одинаковое, с небольшим перевесом у IPhone (36%). Hаспределение доли платящих по всем устройстам примерно одинаково и является очень низким - практически не превышает 6%.
#
#
# 3. Треть всех пользователей пришли в приложение самостоятельно (37%).
# Из платных каналов привлечения самым плодотворным является *FaceBoom* и по общему числу привлечённых пользователей (19.4%) и по доле платящих в нём (12%).
# Канал  *TipTop* привлекает 13% пользователей, однако доля платящих на этом канале - всего 9.6%.
# Yа каналах *AdNonSense* и *lambdaMediaAds*, несмотря на низкий процент привлечения пользователей (2.6% и 1.4%), доля платящих в них 10,5-11%, то есть практически как у лидера FaceBoom. То есть потенциально эти две платформы могут приносить больше денег, если увеличить в них общее число пользователей.
#
#
# 4. Общая сумма расходов на маркетинг составила 105 497 рублей. Из них больше половины всех расходов на рекламу были направлены на канал TipTop (52%), ещё почти треть - на FaceBoom (31%). На оставшиеся 8 источников в сумме пришлось лишь 17% всех рекламных расходов.
#
#
# 5. Общая тенденция расходов на рекламу за последние 6 месяцев - их увеличение. При этом если смотреть распределение по каналам, то увеличение расходов происходило только в отношении каналов TipTop и FaceBoom. При этом в TipTop владывали денег больше всего: начиная с июня вливания в рекаламу на TipTop увеличивалось с каждым месяцем в 1.5-2 раза, а в октябре и достигло пика за весь рассматриваемый период.
#
#
# 6. Средняя стоимость привлечения пользователя в TipTop с каждым месяцем только росла (показатель в 1,5-2 раза выше предыдущего месяца), при этом динамика по остальным каналам практически не менялась.
#
#
# 7. Общая выручка от пользователей выросла, но при этом выросла и стоимость их привлечения. При этом реклама не окупается вовсе - в концу второй недели показатель ROI чуть выше 80%. В динамике окупаемость рекламы стала пропадать как раз тогда, когда подскочили расходы на привлечение пользователей.
#
#
# 8. Из всех стран только **в США реклама не окупается вообще** из-за низкого удержание платящих пользователей и высокой стоимости привлечения пользователей.
#     В июне во всех странах, кроме США резко упала конверсия и далее практически не росла.
#     Динамика удержания в странах (кроме США) скачкообразная - возможно резкие взлёты и падения связаны с какими-то рекламными компаниями:
#     - Великобритания: середина июня - резкий скачок, начало августа - падение,
#     - Франция: конец июля, начало сентября и начало октября - скачки, начало августа - падение,
#     - Германия: середина июля, середина сентября, конец октября - скачки, середина мая, конец июня, середина октября - падения.
#
#
# 9. Из каналов привлечения **хуже всего окупаются TipTop и FaceBoom**.
#     Низкая окупаемость FaceBoom объясняется низким удержанием платящих пользователей.
#     TipTop не окупается из-за совокупности низкой конверсии и высокой стоимости привлечения пользователей.
#     Кроме того обращаем внимание на то, что конверсия в платящих пользователей по всем каналам очень низкая, что влияет в том числе на окупаемость рекламы и общую выручку в целом.
#
#
# 10. Реклама на устройствах **Mac, IPhone И Android вообще не окупаются**.
#     Из всех устройств окупаемость есть только у рекламы на устройстве PC и только с 11 дня привлечения. На этом устройстве окупаемость резко пошла вниз с августа, а с сентября реклама на устройстве не окупается вообще.
#     Cтоимость привлечения на устройствах Mac и IPhone выше, чем на Android и PC.
#     Динамика по всем устройствам показывает общее снижение окупаемости рекламы уже с июня.
#     Конверсия в платящих пользователей на PC самая низкая, однако на этом устройстве самый высокий показатель удержания. На Mac и IPhone, наоборот: высокая конверсия при низком удержании.
#
#     В конце мая и в середине июля наблюдались резкие скачки в удержании платящих пользователей на Мас и IPhone. Аналогичный скачок наблюдается у пользователей PC в середине мая. Стоит проверить эти временные отрезки - возможно в эти периоды события или проводились рекламные компании, которые привели к росту удержания на этих устройствах.

# %% [markdown]
# ### Рекомендации

# %% [markdown]
# **Для повышения общей эффективности рекламной компании рекомендуем:**
#
# 1. Увеличить удержание платящих пользователей и снизить стоимость привлечения пользователей:
#     - в США (на эту страну приходится больше всего пользователей, в том числе платящих),
#     - на устройствах Mac и IPhone.
#
#
# 2. Увеличить конверсию в платящих пользователей и снизить стоимость привлечения пользователей:
#     - в рекламных источниках TipTop.
#
#
# 3. Увеличить удержание платящих пользователей:
#     - в рекламных источниках FaceBoom.
#
#
# 4. Увеличить конверсию в платящих пользователей:
#     - во всех рекламных источниках,
#     - на устройстве PC,
#     - во всех странах, кроме США.
#
#
# 4. Проверить, какие события произошли в середине-конце мая и в середине июля, которые привели к росту удержания на устройствах Мас, IPhone и PC.
#
#
# 5. Проверить какие события произошли в конце мая-начале июня и привели к резкому снижению конверсии во Франции, Германии и Великобритании.
#
#
# 6. Проверить, какие события произошли в следующие периоды и привели к резким скачкам в динами удержания в странах:
#     - Великобритания: середина июня - резкий скачок, начало августа - падение,
#     - Франция: конец июля, начало сентября и начало октября - скачки, начало августа - падение,
#     - Германия: середина июля, середина сентября, конец октября - скачки, середина мая, конец июня, середина октября - падения.
#
#
# 7. Увеличить число пользователей на каналах AdNonSense и lambdaMediaAds, так как потенциально в этих источниках больше всего доля платящих пользователей.
